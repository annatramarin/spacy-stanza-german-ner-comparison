# %%
# The initial command would be the following, but in this case I had to upgrade datasets
# !pip install datasets

# !pip install -q --upgrade datasets

# %% [markdown]
# ## Import a dataset of news headlines in German

# %%
# Load this dataset: https://huggingface.co/datasets/Jotschi/german-news-titles
from datasets import load_dataset

ds = load_dataset("Jotschi/german-news-titles")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/830 [00:00<?, ?B/s]
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# train_dataset.json: 0.00B [00:00, ?B/s]
# test_dataset.json: 0.00B [00:00, ?B/s]
# ...
# Generating test split:   0%|          | 0/257 [00:00<?, ? examples/s]

# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)

df = pd.DataFrame(ds['train'])
df.head(10)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
titles_from_df = df['titles'].tolist()
print(titles_from_df[0])
# Out:
# ['Innovative Architektur und Stadtentwicklung in Frankfurt am Main: Das Europaviertel und Campus Towers setzen neue Maßstäbe', 'Wie nachhaltige Bebauung und öffentliche Räume das Leben in der Stadt verbessern können - Erfolgsgeschichte Frankfurt am Main', 'Die Zukunft des urbanen Lebens: Architektur und Stadtentwicklung im Europaviertel und Campus Towers, Frankfurt am Main', 'Moderne Gebäude und ökologische Bauweisen in Frankfurt am Main - Nachhaltigkeit im Fokus', 'Radentscheid Frankfurt: Wie der Ausbau von Radwegen den Verkehr in urbanen Räumen verbessern kann', 'Die Bedeutung von öffentlichen Räumen und nachhaltiger Architektur für das Wohlbefinden in Städten - Einblicke aus Frankfurt am Main', 'Wie die Stadt Frankfurt am Main zur umweltfreundlichen Metropole avanciert: Von ökologischen Gebäuden bis hin zu Radwegen', 'Die Renaissance des städtischen Lebensraums: Erfolgsgeschichte Frankfurt am Main und ihre Lektionen für andere Städte', 'Architektur und Stadtentwicklung im Spannung
# ...

# %%
type(titles_from_df[0])
# Out:
# list

# %%
# titles_from_df is a list of lists
# convert it to a list of strings

titles=[]

for sublist in titles_from_df:
  for item in sublist:
    titles.append(item)

print(titles[0])
# Out:
# Innovative Architektur und Stadtentwicklung in Frankfurt am Main: Das Europaviertel und Campus Towers setzen neue Maßstäbe

# %%
len(titles)
# Out:
# 16860

# %% [markdown]
# ## Apply spaCy's German NER on titles

# %% [markdown]
# # Test the small German model

# %%
# !python -m spacy download de_core_news_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 86.6 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('de_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
# Process news titles with spaCy's German language model

import spacy

# Test model on one sentence
nlp_spacy_sm = spacy.load('de_core_news_sm')
doc_sentence = nlp_spacy_sm(titles[0])
print(doc_sentence.text)

# Check the entities
for token in doc_sentence:
  print(token.text, token.ent_type_)
# Out:
# Innovative Architektur und Stadtentwicklung in Frankfurt am Main: Das Europaviertel und Campus Towers setzen neue Maßstäbe
# Innovative
# Architektur
# und
# Stadtentwicklung
# in
# Frankfurt LOC
# am LOC
# Main LOC
# :
# Das
# Europaviertel
# und
# Campus MISC
# Towers MISC
# setzen
# neue
# Maßstäbe

# %%
# Apply the model to the whole document
doc_spacy_sm = [nlp_spacy_sm(title) for title in titles]

# %%
# Visualize a few examples:
for sentence in doc_spacy_sm[:3]:
  print(sentence.text)
  print("---")
  for ent in sentence.ents:
    print(ent.text, ent.label_)
  print("---------------------------------------------------------")
# Out:
# Innovative Architektur und Stadtentwicklung in Frankfurt am Main: Das Europaviertel und Campus Towers setzen neue Maßstäbe
# ---
# Frankfurt am Main LOC
# Campus Towers MISC
# ---------------------------------------------------------
# Wie nachhaltige Bebauung und öffentliche Räume das Leben in der Stadt verbessern können - Erfolgsgeschichte Frankfurt am Main
# ---
# Stadt LOC
# Frankfurt am Main LOC
# ---------------------------------------------------------
# Die Zukunft des urbanen Lebens: Architektur und Stadtentwicklung im Europaviertel und Campus Towers, Frankfurt am Main
# ---
# Campus Towers ORG
# Frankfurt am Main LOC
# ---------------------------------------------------------

# %%
# Save data as a csv file

import pandas as pd

rows=[]

for i, doc in enumerate(doc_spacy_sm):
  for ent in doc.ents:
    rows.append({
        'title': titles[i],
        'entity': ent.text,
        'label': ent.label_
                 })

df_spacy_sm = pd.DataFrame(rows)
df_spacy_sm.to_csv('df_spacy_sm.csv', index=False)

# %%
df_spacy_sm.head(10)
# Out:
#                                                                                                                                   title  \
# 0            Innovative Architektur und Stadtentwicklung in Frankfurt am Main: Das Europaviertel und Campus Towers setzen neue Maßstäbe
# 1            Innovative Architektur und Stadtentwicklung in Frankfurt am Main: Das Europaviertel und Campus Towers setzen neue Maßstäbe
# 2         Wie nachhaltige Bebauung und öffentliche Räume das Leben in der Stadt verbessern können - Erfolgsgeschichte Frankfurt am Main
# 3         Wie nachhaltige Bebauung und öffentliche Räume das Leben in der Stadt verbessern können - Erfolgsgeschichte Frankfurt am Main
# 4                Die Zukunft des urbanen Lebens: Architektur und Stadtentwicklung im Europaviertel und Campus Towers, Frankfurt am Main
# 5                Die Zukunft des urbanen Lebens: Architektur und Stadtentwicklung im Europaviertel und Campus Towers, Frankfurt am Main
# ...

# %% [markdown]
# # Test the medium German model

# %%
# !python -m spacy download de_core_news_md
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 MB 17.0 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('de_core_news_md')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
nlp_spacy_md = spacy.load('de_core_news_md')

doc_md = [nlp_spacy_md(title) for title in titles]

# %%
# Visualize a few examples:
for sentence in doc_md[:3]:
  print(sentence.text)
  print("---")
  for ent in sentence.ents:
    print(ent.text, ent.label_)
  print("---------------------------------------------------------")
# Out:
# Innovative Architektur und Stadtentwicklung in Frankfurt am Main: Das Europaviertel und Campus Towers setzen neue Maßstäbe
# ---
# Frankfurt am Main LOC
# Europaviertel LOC
# Campus Towers LOC
# ---------------------------------------------------------
# Wie nachhaltige Bebauung und öffentliche Räume das Leben in der Stadt verbessern können - Erfolgsgeschichte Frankfurt am Main
# ---
# Stadt LOC
# ---------------------------------------------------------
# Die Zukunft des urbanen Lebens: Architektur und Stadtentwicklung im Europaviertel und Campus Towers, Frankfurt am Main
# ---
# Europaviertel LOC
# Campus Towers LOC
# Frankfurt am Main LOC
# ---------------------------------------------------------

# %%
# Save data as a csv file
rows=[]

for i, doc in enumerate(doc_md):
  for ent in doc.ents:
    rows.append({
        'title': titles[i],
        'entity': ent.text,
        'label': ent.label_
                 })

df_spacy_md = pd.DataFrame(rows)
df_spacy_md.to_csv('df_spacy_md.csv', index=False)

# %%
df_spacy_md.head(10)
# Out:
#                                                                                                                                   title  \
# 0            Innovative Architektur und Stadtentwicklung in Frankfurt am Main: Das Europaviertel und Campus Towers setzen neue Maßstäbe
# 1            Innovative Architektur und Stadtentwicklung in Frankfurt am Main: Das Europaviertel und Campus Towers setzen neue Maßstäbe
# 2            Innovative Architektur und Stadtentwicklung in Frankfurt am Main: Das Europaviertel und Campus Towers setzen neue Maßstäbe
# 3         Wie nachhaltige Bebauung und öffentliche Räume das Leben in der Stadt verbessern können - Erfolgsgeschichte Frankfurt am Main
# 4                Die Zukunft des urbanen Lebens: Architektur und Stadtentwicklung im Europaviertel und Campus Towers, Frankfurt am Main
# 5                Die Zukunft des urbanen Lebens: Architektur und Stadtentwicklung im Europaviertel und Campus Towers, Frankfurt am Main
# ...

# %% [markdown]
# # Test the large German model

# %%
# !python -m spacy download de_core_news_lg
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 567.8/567.8 MB 2.4 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('de_core_news_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
nlp_spacy_lg = spacy.load('de_core_news_lg')

doc_lg = [nlp_spacy_lg(title) for title in titles]

# %%
# Visualize a few examples:
for sentence in doc_lg[:3]:
  print(sentence.text)
  print("---")
  for ent in sentence.ents:
    print(ent.text, ent.label_)
  print("---------------------------------------------------------")
# Out:
# Innovative Architektur und Stadtentwicklung in Frankfurt am Main: Das Europaviertel und Campus Towers setzen neue Maßstäbe
# ---
# Frankfurt am Main LOC
# Europaviertel LOC
# Campus Towers LOC
# ---------------------------------------------------------
# Wie nachhaltige Bebauung und öffentliche Räume das Leben in der Stadt verbessern können - Erfolgsgeschichte Frankfurt am Main
# ---
# Stadt LOC
# Frankfurt am Main LOC
# ---------------------------------------------------------
# Die Zukunft des urbanen Lebens: Architektur und Stadtentwicklung im Europaviertel und Campus Towers, Frankfurt am Main
# ---
# Europaviertel LOC
# Campus Towers LOC
# Frankfurt am Main LOC
# ---------------------------------------------------------

# %%
# Save data as a csv file
rows=[]

for i, doc in enumerate(doc_lg):
  for ent in doc.ents:
    rows.append({
        'title': titles[i],
        'entity': ent.text,
        'label': ent.label_
                 })

df_spacy_lg = pd.DataFrame(rows)
df_spacy_lg.to_csv('df_spacy_lg.csv', index=False)

# %%
df_spacy_lg.head(10)
# Out:
#                                                                                                                                   title  \
# 0            Innovative Architektur und Stadtentwicklung in Frankfurt am Main: Das Europaviertel und Campus Towers setzen neue Maßstäbe
# 1            Innovative Architektur und Stadtentwicklung in Frankfurt am Main: Das Europaviertel und Campus Towers setzen neue Maßstäbe
# 2            Innovative Architektur und Stadtentwicklung in Frankfurt am Main: Das Europaviertel und Campus Towers setzen neue Maßstäbe
# 3         Wie nachhaltige Bebauung und öffentliche Räume das Leben in der Stadt verbessern können - Erfolgsgeschichte Frankfurt am Main
# 4         Wie nachhaltige Bebauung und öffentliche Räume das Leben in der Stadt verbessern können - Erfolgsgeschichte Frankfurt am Main
# 5                Die Zukunft des urbanen Lebens: Architektur und Stadtentwicklung im Europaviertel und Campus Towers, Frankfurt am Main
# ...

# %% [markdown]
# ## Apply stanza's German NER on titles
#
# Refer to [Stanza-Beginners-Guide.ipynb](https://colab.research.google.com/github/stanfordnlp/stanza/blob/master/demo/Stanza_Beginners_Guide.ipynb#scrollTo=HDwRm-KXGcYo) and [Stanza - Named Entity Recognition](https://stanfordnlp.github.io/stanza/ner.html#accessing-named-entity-recogition-ner-tags-for-token)

# %%
# !pip install stanza
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 27.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 773.7/773.7 kB 29.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.4/608.4 kB 43.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 418.7/418.7 kB 19.3 MB/s eta 0:00:00
# ...

# %%
import stanza

stanza.download('de')
# Out:
# ...
# INFO:stanza:Downloaded file to /root/.cache/stanza/1.11.0/resources/resources.json
# INFO:stanza:Downloading default packages for language: de (German) ...
# ...
# INFO:stanza:Downloaded file to /root/.cache/stanza/1.11.0/resources/de/default.zip
# INFO:stanza:Finished downloading models and saved to /root/.cache/stanza/1.11.0/resources
# [['zip', 'default.zip']]

# %%
nlp_stanza = stanza.Pipeline('de', processors='tokenize, ner')
# Out:
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# ...
# INFO:stanza:Downloaded file to /root/.cache/stanza/1.11.0/resources/resources.json
# WARNING:stanza:Language de package default expects mwt, which has been added
# INFO:stanza:Loading these models for language: de (German):
# ...
# | Processor | Package      |
# ----------------------------
# | tokenize  | combined     |
# | mwt       | combined     |
# | ner       | germeval2014 |
# ...
#
# INFO:stanza:Using device: cuda
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: mwt
# INFO:stanza:Loading: ner
# INFO:stanza:Done loading processors!

# %%
doc_sentence_stanza = nlp_stanza(titles[0])

for sent in doc_sentence_stanza.sentences:
  print(sent.text)
  for ent in sent.ents:
    print(ent.text, ent.type)
# Out:
# Innovative Architektur und Stadtentwicklung in Frankfurt am Main: Das Europaviertel und Campus Towers setzen neue Maßstäbe
# Frankfurt am Main LOC
# Campus Towers LOC

# %%
# Use the GPU as the CPU would take a long time to process

nlp_stanza_gpu = stanza.Pipeline('de', processors = 'tokenize,ner', use_gpu= True)
# Out:
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# ...
# INFO:stanza:Downloaded file to /root/.cache/stanza/1.11.0/resources/resources.json
# WARNING:stanza:Language de package default expects mwt, which has been added
# INFO:stanza:Loading these models for language: de (German):
# ...
# | Processor | Package      |
# ----------------------------
# | tokenize  | combined     |
# | mwt       | combined     |
# | ner       | germeval2014 |
# ...
#
# INFO:stanza:Using device: cuda
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: mwt
# INFO:stanza:Loading: ner
# INFO:stanza:Done loading processors!

# %%
# Use tqdm to keep tracking of processing progress

from tqdm import tqdm
doc_stanza = [nlp_stanza_gpu(title) for title in tqdm(titles)]
# Out:
# 100%|██████████| 16860/16860 [09:10<00:00, 30.61it/s]

# %%
# Visualize a few examples:
for sentence in doc_stanza[:3]:
  print(sentence.text)
  print("---")
  for ent in sentence.ents:
      print(ent.text,ent.type)
  print("---------------------------------------------------------")
# Out:
# Innovative Architektur und Stadtentwicklung in Frankfurt am Main: Das Europaviertel und Campus Towers setzen neue Maßstäbe
# ---
# Frankfurt am Main LOC
# Campus Towers LOC
# ---------------------------------------------------------
# Wie nachhaltige Bebauung und öffentliche Räume das Leben in der Stadt verbessern können - Erfolgsgeschichte Frankfurt am Main
# ---
# Frankfurt am Main LOC
# ---------------------------------------------------------
# Die Zukunft des urbanen Lebens: Architektur und Stadtentwicklung im Europaviertel und Campus Towers, Frankfurt am Main
# ---
# Europaviertel LOC
# Campus Towers LOC
# Frankfurt am Main LOC
# ---------------------------------------------------------

# %%
# Save data as a csv file
rows=[]

for i, doc in enumerate(doc_stanza):
  for ent in doc.ents:
    rows.append({
        'title': titles[i],
        'entity': ent.text,
        'label': ent.type
                 })

df_stanza = pd.DataFrame(rows)
df_stanza.to_csv('df_stanza.csv', index=False)

# %%
df_stanza.head(10)
# Out:
#                                                                                                                                   title  \
# 0            Innovative Architektur und Stadtentwicklung in Frankfurt am Main: Das Europaviertel und Campus Towers setzen neue Maßstäbe
# 1            Innovative Architektur und Stadtentwicklung in Frankfurt am Main: Das Europaviertel und Campus Towers setzen neue Maßstäbe
# 2         Wie nachhaltige Bebauung und öffentliche Räume das Leben in der Stadt verbessern können - Erfolgsgeschichte Frankfurt am Main
# 3                Die Zukunft des urbanen Lebens: Architektur und Stadtentwicklung im Europaviertel und Campus Towers, Frankfurt am Main
# 4                Die Zukunft des urbanen Lebens: Architektur und Stadtentwicklung im Europaviertel und Campus Towers, Frankfurt am Main
# 5                Die Zukunft des urbanen Lebens: Architektur und Stadtentwicklung im Europaviertel und Campus Towers, Frankfurt am Main
# ...
